# %%
ディレクトリ構成

# %%
notebook/
└── tenhou_source_data/
    ├── tenhou_zip/
    │   ├── scraw2009.zip
    │   ├── scraw2010.zip
    │   └── ...
    ├── tenhou_url_2009_2023/
    │   ├── scc20090101.html
    │   ├── scc20090102.html
    │   ├── scc20090103.html
    │   └── ...
    └── tenhou_haifu/
        ├── tenhou_haifu_2009_05_13_05_15.xml
        ├── tenhou_haifu_2009_05_13_05_30.xml
        ├── tenhou_haifu_2009_05_13_06_45.xml
        └── ...

# %% [markdown]
# ### `https://tenhou.net/sc/raw/`から手動でダウンロードした年度別zipファイルを解凍し、年度別ファイルを作成

# %% [markdown]
# tenhou_zipフォルダ内のzipファイルから鳳凰卓のデータ（scc.html.gz）を解凍・抽出する

# %%
import zipfile
import gzip
import os
from pathlib import Path

# tenhou_zip フォルダ内の zip ファイルを取得
zip_dir = Path("tenhou_source_data/tenhou_zip")
zip_files = sorted(zip_dir.glob("scraw*.zip"))  # scraw2009.zip〜scraw2023.zip などを対象

# 年の範囲を zip ファイル名から抽出
years = sorted({int(z.name[5:9]) for z in zip_files})
year_range_str = f"{years[0]}_{years[-1]}" if years else "unknown"

# 出力ディレクトリ（年の範囲を含める）
output_root = Path(f"tenhou_source_data/tenhou_url_{year_range_str}")

for zip_path in zip_files:
    zip_file_name = zip_path.name
    year = zip_file_name[5:9]  # "2019" などを抽出
    output_dir = output_root / year
    output_dir.mkdir(parents=True, exist_ok=True)

    with zipfile.ZipFile(zip_path, 'r') as zf:
        for file_info in zf.infolist():
            if file_info.filename.startswith(f"{year}/scc") and (file_info.filename.endswith(".html.gz") or file_info.filename.endswith(".html")):
                with zf.open(file_info) as file:
                    base_name = os.path.basename(file_info.filename).replace(".gz", "")
                    output_path = output_dir / base_name
                    if file_info.filename.endswith(".html.gz"):
                        with gzip.open(file, 'rb') as html_file:
                            with open(output_path, 'wb') as out_f:
                                out_f.write(html_file.read())
                    else:
                        # .htmlファイルの場合はそのままコピー
                        with open(output_path, 'wb') as out_f:
                            out_f.write(file.read())

print(f"解凍と分類が完了しました（出力先: {output_root}）。")
# Out:
# 解凍と分類が完了しました（出力先: tenhou_source_data\tenhou_url_2009_2023）。

# %% [markdown]
# ### 作成したファイルからHTML内のリンクを抽出し、テーブルデータに整理(フォルダ作成処理が完了していたらここから進める)

# %% [markdown]
# tenhou_url_2009_2023をテーブルデータに格納する

# %%
import os
from pathlib import Path
import pandas as pd
from bs4 import BeautifulSoup
import re

# === 1. パラメータ指定 ===
file_path = "tenhou_source_data/tenhou_url_2009_2023"
year_range = range(2009, 2024)  # 2009〜2023年
date_range = ("0101", "1231")   # MMDD形式

# 範囲の最初と最後を取得
start_year = year_range[0]
end_year = year_range[-1]

# === 2. ディレクトリ初期化 ===
base_dir = Path(file_path)
selected_files = []

# === 3. 対象ファイルの抽出 ===
for year in year_range:
    year_dir = base_dir / str(year)
    if not year_dir.exists():
        continue
    for file in year_dir.glob("scc*.html"):
        date_str = file.stem[3:11]  # 'scc20200201' → '20200201'
        if date_str.startswith(str(year)):
            mmdd = date_str[4:]
            if date_range[0] <= mmdd <= date_range[1]:
                selected_files.append(file)

# === 4. HTMLからデータ抽出する関数（改良版） ===
def parse_html_file(filepath):
    with open(filepath, encoding="utf-8") as f:
        soup = BeautifulSoup(f, "html.parser")

    # <br>, <br/>, <br /> すべてのパターンに対応して分割
    lines = re.split(r"<br\s*/?>", soup.decode_contents())
    parsed = []

    for line in lines:
        if "href=" not in line:
            continue

        parts = line.split("|")
        if len(parts) < 4:
            continue

        time = parts[0].strip()
        table_type = parts[2].strip()
        url_match = re.search(r'href="([^"]+)"', line)
        url = url_match.group(1) if url_match else None

        # プレイヤーとスコア抽出
        score_part = parts[4] if len(parts) > 4 else ""
        player_scores = re.findall(r'([^\(]+)\(([-+]?\d+(?:\.\d+)?)\)', score_part)

        # 結果を辞書に格納
        record = {
            "file": filepath.name,
            "time": time,
            "table_type": table_type,
            "url": url
        }

        for i in range(4):
            if i < len(player_scores):
                name, score = player_scores[i]
                record[f"player{i+1}"] = name.strip()
                record[f"score{i+1}"] = float(score)
            else:
                record[f"player{i+1}"] = None
                record[f"score{i+1}"] = None

        parsed.append(record)

    return parsed


# === 5. 全ファイルから情報を取得してDataFrame化 ===
all_records = []
for file in selected_files:
    all_records.extend(parse_html_file(file))

dataset_url_df = pd.DataFrame(all_records)

# === 6. 表示（初期テーブル表示） ===
# file列から年月日を抽出して新しい列を追加
dataset_url_df['year'] = dataset_url_df['file'].str.extract(r'(\d{4})').astype(int)
dataset_url_df['month'] = dataset_url_df['file'].str.extract(r'\d{4}(\d{2})').astype(int)
dataset_url_df['day'] = dataset_url_df['file'].str.extract(r'\d{6}(\d{2})').astype(int)

# URLを閲覧用のリンクではなくxmlのリンクに変更
dataset_url_df['url'] = dataset_url_df['url'].str.replace('?log=', 'log/?')

# table_typeの－を削除
dataset_url_df['table_type'] = dataset_url_df['table_type'].str.replace('－', '')

# 日付列を結合して作成
dataset_url_df['date'] = pd.to_datetime(dataset_url_df[['year', 'month', 'day']])


# 表示
pd.set_option('display.max_columns', None)
display(dataset_url_df.head())
# 行と列の数を表示
print(dataset_url_df.shape)
# Out:
#                file   time table_type  \
# 0  scc20090201.html  03:18      四鳳南喰赤
# 1  scc20090201.html  03:41      四鳳南喰赤
# 2  scc20090220.html  11:10      四鳳南喰赤
# 3  scc20090220.html  11:15      四鳳東喰赤
# 4  scc20090220.html  11:22      四鳳東喰赤
#
#                                                  url   player1  score1  \
# 0  http://tenhou.net/0/log/?2009020103gm-00a9-000...  EXAMPLE2    47.0
# 1  http://tenhou.net/0/log/?2009020103gm-00a9-000...   EXAMPLE    38.0
# 2  http://tenhou.net/0/log/?2009022011gm-00a9-000...   LITHIUM    46.0
# 3  http://tenhou.net/0/log/?2009022011gm-00e1-000...   六分儀ゲンドウ    32.0
# 4  http://tenhou.net/0/log/?2009022011gm-00e1-000...    闘士☆渋川老    37.0
#
#     player2  score2   player3  score3   player4  score4  year  month  day  \
# 0   EXAMPLE     1.0  EXAMPLE4   -19.0  EXAMPLE3   -29.0  2009      2    1
# 1  EXAMPLE2     4.0  EXAMPLE4   -16.0  EXAMPLE3   -26.0  2009      2    1
# 2       三河屋    15.0      三田村茜   -10.0      チャオリ   -51.0  2009      2   20
# 3     超ヒモリロ     1.0  NONSTYLE   -13.0     メタファー   -20.0  2009      2   20
# 4    bakase     6.0    平均順位重視   -14.0       AmA   -29.0  2009      2   20
#
#         date
# 0 2009-02-01
# 1 2009-02-01
# 2 2009-02-20
# 3 2009-02-20
# 4 2009-02-20
# (3706017, 16)

# %% [markdown]
# 重複列の確認

# %%
# プレイヤー3人の順番を無視して比較するため、新しい列を作る
df = dataset_url_df.copy()

# プレイヤー3人の順番を無視して集合にする
df['player_set'] = df[['player1', 'player2', 'player3']].apply(lambda x: frozenset(x), axis=1)

# 重複判定キー（player_set, date, time の組み合わせ）
df['dup_key'] = list(zip(df['player_set'], df['date'], df['time']))

# 重複行を抽出
duplicated_rows = df[df.duplicated('dup_key', keep=False)]

# 結果表示
display(duplicated_rows)
# Out:
# Empty DataFrame
# Columns: [file, time, table_type, url, player1, score1, player2, score2, player3, score3, player4, score4, year, month, day, date, player_set, dup_key]
# Index: []

# %% [markdown]
# ### urlをテーブルで指定してから、スクレイピングしてXMLファイルを取得する

# %% [markdown]
# 使用するデータセットの指定

# %%
# 卓の指定(三人麻雀)
table = '三鳳南喰赤'

# 日付範囲の指定(すべての期間: 2009~2023)
start_date = pd.Timestamp('2009-01-01')
end_date = pd.Timestamp('2023-12-31')

# 日付列を結合して作成
dataset_url_df['date'] = pd.to_datetime(dataset_url_df[['year', 'month', 'day']])

# 条件定義
condition_table = dataset_url_df['table_type'] == table
condition_date = dataset_url_df['date'].between(start_date, end_date)
# 不正プレイヤーを含む対戦を除外
condition_player = ~(
    (dataset_url_df['player1'] == 'くうた') | 
    (dataset_url_df['player2'] == 'くうた') | 
    (dataset_url_df['player3'] == 'くうた')
)

# 条件で抽出
dataset_sanma_url_df = dataset_url_df[
    condition_table
    & condition_date  
    & condition_player
]

# 結果を表示
display(dataset_sanma_url_df)
# Out:
#                      file   time table_type  \
# 72       scc20090220.html  17:10      三鳳南喰赤
# 77       scc20090220.html  17:32      三鳳南喰赤
# 79       scc20090220.html  17:49      三鳳南喰赤
# 83       scc20090220.html  18:10      三鳳南喰赤
# 86       scc20090220.html  18:21      三鳳南喰赤
# ...                   ...    ...        ...
# 3705999  scc20231231.html  23:32      三鳳南喰赤
# 3706002  scc20231231.html  23:36      三鳳南喰赤
# 3706006  scc20231231.html  23:42      三鳳南喰赤
# 3706009  scc20231231.html  23:46      三鳳南喰赤
# 3706012  scc20231231.html  23:50      三鳳南喰赤
#
#                                                        url   player1  score1  \
# 72       http://tenhou.net/0/log/?2009022017gm-00b9-000...       俊ころ    44.0
# 77       http://tenhou.net/0/log/?2009022017gm-00b9-000...     楠下幾太郎    35.0
# 79       http://tenhou.net/0/log/?2009022017gm-00b9-000...     我々クラス    45.0
# 83       http://tenhou.net/0/log/?2009022018gm-00b9-000...     楠下幾太郎    46.0
# 86       http://tenhou.net/0/log/?2009022018gm-00b9-000...      蜜柑の皮    37.0
# ...                                                    ...       ...     ...
# 3705999  http://tenhou.net/0/log/?2023123123gm-00b9-000...      REBI    42.5
# 3706002  http://tenhou.net/0/log/?2023123123gm-00b9-000...     ホンミン。    54.5
# 3706006  http://tenhou.net/0/log/?2023123123gm-00b9-000...  樽なの壊さないで    60.0
# 3706009  http://tenhou.net/0/log/?2023123123gm-00b9-000...      理論力学    51.6
# 3706012  http://tenhou.net/0/log/?2023123123gm-00b9-000...      ストラ！    38.6
#
#          player2  score2 player3  score3 player4  score4  year  month  day  \
# 72       僕、おおくぽん   -10.0   楠下幾太郎   -34.0    None     NaN  2009      2   20
# 77       僕、おおくぽん    -3.0    オカルト   -32.0    None     NaN  2009      2   20
# 79           ジュン   -10.0   楠下幾太郎   -35.0    None     NaN  2009      2   20
# 83       僕、おおくぽん     5.0   我々クラス   -51.0    None     NaN  2009      2   20
# 86         楠下幾太郎    -1.0   我々クラス   -36.0    None     NaN  2009      2   20
# ...          ...     ...     ...     ...     ...     ...   ...    ...  ...
# 3705999    おかあさん     2.9    理論力学   -45.4    None     NaN  2023     12   31
# 3706002     高部軍団   -16.2  パクチうま夫   -38.3    None     NaN  2023     12   31
# 3706006    おかあさん   -15.6  マッスルカズ   -44.4    None     NaN  2023     12   31
# 3706009    ガーネット    -2.1     らくた   -49.5    None     NaN  2023     12   31
# 3706012   とりてん10    -4.5   zkurt   -34.1    None     NaN  2023     12   31
#
#               date
# 72      2009-02-20
# 77      2009-02-20
# 79      2009-02-20
# 83      2009-02-20
# 86      2009-02-20
# ...            ...
# 3705999 2023-12-31
# 3706002 2023-12-31
# 3706006 2023-12-31
# 3706009 2023-12-31
# 3706012 2023-12-31
#
# [861222 rows x 16 columns]

# %% [markdown]
# 指定された URL リストから Tenhou 牌譜 XML をダウンロードする
# - 年度別フォルダへ保存
#   - ファイル名にインデックスを含めて一意化
# - バッチ処理
#   - 一度に n 件ずつ（例：300 件）に分割して順次実行
# - 既存ファイルのスキップ
#   - 同名ファイルが存在する場合はダウンロードをスキップ
# - エラー時のハンドリング
#   - HTTP ステータス 404／410 は即スキップ＆ログ記録
#   - その他ネットワークエラーは指数バックオフで最大リトライ
# - 進捗表示
#   - コンソール上にバッチ単位のプログレスバーを表示

# %%
import os
import requests
import time
import xml.dom.minidom
import pandas as pd
import logging

base_folder = "tenhou_source_data/tenhou_haifu"
batch_size = 300
max_retries = 5  # 最大リトライ回数

# ロギング設定
log_folder = "logs"
os.makedirs(log_folder, exist_ok=True)
logging.basicConfig(
    filename=os.path.join(log_folder, "error_urls.log"),
    level=logging.ERROR,
    format="%(asctime)s [%(levelname)s] %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
)

total_rows = len(dataset_sanma_url_df)
total_batches = (total_rows + batch_size - 1) // batch_size
bar_length = 25

for i in range(0, total_rows, batch_size):
    batch_df = dataset_sanma_url_df.iloc[i:i + batch_size]

    for idx, row in batch_df.iterrows():
        url = row['url']
        date_str = row['date'].strftime("%Y_%m_%d")
        time_str = row['time'].replace(":", "_")
        year_folder = os.path.join(base_folder, str(row['year']))
        os.makedirs(year_folder, exist_ok=True)

        filename = os.path.join(
            year_folder,
            f"tenhou_haifu_{date_str}_{time_str}_{idx}.xml"
        )

        if os.path.exists(filename):
            #print(f"⚠️ 既存ファイルをスキップ: {filename}")
            continue

        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
        }

        retry = 0
        while True:
            try:
                response = requests.get(url, headers=headers, timeout=10)
                # ステータスコードチェック
                if response.status_code in (404, 410):
                    msg = f"スキップ(HTTP {response.status_code}) index={idx}: {url}"
                    print("⚠️ " + msg)
                    logging.error(msg)
                    break

                response.raise_for_status()
                dom = xml.dom.minidom.parseString(response.text)
                with open(filename, "w", encoding="utf-8") as f:
                    f.write(dom.toprettyxml(indent="  "))
                break  # 成功したらループ抜け

            except requests.exceptions.HTTPError as e:
                # 上記で404/410は処理済みなのでその他のHTTPエラー
                retry += 1
                if retry > max_retries:
                    msg = f"URLスキップ(index={idx}, retries={retry}): {url} - HTTPError {e.response.status_code}"
                    print("❌ " + msg)
                    logging.error(msg)
                    break
                wait = 2 ** retry
                print(f"❌ HTTPError({e.response.status_code}) index={idx} - リトライ {retry}/{max_retries} 待機:{wait}s")
                time.sleep(wait)

            except Exception as e:
                retry += 1
                if retry > max_retries:
                    msg = f"URLスキップ(index={idx}, retries={retry}): {url} - {e}"
                    print("❌ " + msg)
                    logging.error(msg)
                    break
                wait = 2 ** retry
                print(f"❌ エラー(index={idx}): {e} - リトライ {retry}/{max_retries} 待機:{wait}s")
                time.sleep(wait)

    # プログレスバー表示
    current_batch = i // batch_size + 1
    progress = current_batch / total_batches
    bar = '█' * int(bar_length * progress) + '-' * (bar_length - int(bar_length * progress))
    print(f"\r🕒 バッチ {current_batch}/{total_batches} 完了 [{bar}] {progress*100:.1f}%", end='')

print("\n✅ 全バッチ処理完了！")
# Out:
# 🕒 バッチ 110/2871 完了 [-------------------------] 3.8%❌ エラー(index=126669): duplicate attribute: line 1, column 10481 - リトライ 1/5 待機:2s
# ❌ エラー(index=126669): duplicate attribute: line 1, column 10481 - リトライ 2/5 待機:4s
# ❌ エラー(index=126669): duplicate attribute: line 1, column 10481 - リトライ 3/5 待機:8s
# ❌ エラー(index=126669): duplicate attribute: line 1, column 10481 - リトライ 4/5 待機:16s
# ❌ エラー(index=126669): duplicate attribute: line 1, column 10481 - リトライ 5/5 待機:32s
# ❌ URLスキップ(index=126669, retries=6): http://tenhou.net/0/log/?2010051023gm-00b9-0000-8cc07cb6 - duplicate attribute: line 1, column 10481
# ❌ エラー(index=126683): duplicate attribute: line 1, column 12663 - リトライ 1/5 待機:2s
# ❌ エラー(index=126683): duplicate attribute: line 1, column 12663 - リトライ 2/5 待機:4s
# ❌ エラー(index=126683): duplicate attribute: line 1, column 12663 - リトライ 3/5 待機:8s
# ❌ エラー(index=126683): duplicate attribute: line 1, column 12663 - リトライ 4/5 待機:16s
# ❌ エラー(index=126683): duplicate attribute: line 1, column 12663 - リトライ 5/5 待機:32s
# ❌ URLスキップ(index=126683, retries=6): http://tenhou.net/0/log/?2010051023gm-00b9-0000-68b257ef - duplicate attribute: line 1, column 12663
# ❌ エラー(index=126685): duplicate attribute: line 1, column 13579 - リトライ 1/5 待機:2s
# ❌ エラー(index=126685): duplicate attribute: line 1, column 13579 - リトライ 2/5 待機:4s
# ❌ エラー(index=126685): duplicate attribute: line 1, column 13579 - リトライ 3/5 待機:8s
# ❌ エラー(index=126685): duplicate attribute: line 1, column 13579 - リトライ 4/5 待機:16s
# ❌ エラー(index=126685): duplicate attribute: line 1, column 13579 - リトライ 5/5 待機:32s
# ❌ URLスキップ(index=126685, retries=6): http://tenhou.net/0/log/?2010051023gm-00b9-0000-6f84ea15 - duplicate attribute: line 1, column 13579
# ❌ エラー(index=126697): duplicate attribute: line 1, column 10877 - リトライ 1/5 待機:2s
# ❌ エラー(index=126697): duplicate attribute: line 1, column 10877 - リトライ 2/5 待機:4s
# ❌ エラー(index=126697): duplicate attribute: line 1, column 10877 - リトライ 3/5 待機:8s
# ❌ エラー(index=126697): duplicate attribute: line 1, column 10877 - リトライ 4/5 待機:16s
# ❌ エラー(index=126697): duplicate attribute: line 1, column 10877 - リトライ 5/5 待機:32s
# ❌ URLスキップ(index=126697, retries=6): http://tenhou.net/0/log/?2010051100gm-00b9-0000-2e91d335 - duplicate attribute: line 1, column 10877
# ❌ エラー(index=126791): duplicate attribute: line 1, column 11801 - リトライ 1/5 待機:2s
# ❌ エラー(index=126791): duplicate attribute: line 1, column 11801 - リトライ 2/5 待機:4s
# ❌ エラー(index=126791): duplicate attribute: line 1, column 11801 - リトライ 3/5 待機:8s
# ❌ エラー(index=126791): duplicate attribute: line 1, column 11801 - リトライ 4/5 待機:16s
# ❌ エラー(index=126791): duplicate attribute: line 1, column 11801 - リトライ 5/5 待機:32s
# ❌ URLスキップ(index=126791, retries=6): http://tenhou.net/0/log/?2010051110gm-00b9-0000-16c602ac - duplicate attribute: line 1, column 11801
# 🕒 バッチ 2871/2871 完了 [█████████████████████████] 100.0%
# ✅ 全バッチ処理完了！

# %% [markdown]
# エラー耐性のあるコード(urlの問題で、特定のindexからエラーが出る場合がある。最後の <RYUUKYOKU> タグ内に同じ owari 属性が２回連続して定義されているため)

# %%
import os
import re
import requests
import time
import xml.dom.minidom
import pandas as pd
import logging

# 生テキストから「同一属性＋同一値」の重複をまとめる関数
def dedupe_attrs(xml_text: str) -> str:
    """
    タグ内で同じ属性="値" が連続している場合を一つにまとめる。
    例: <TAG a="x" a="x" b="y"> → <TAG a="x" b="y">
    """
    pattern = re.compile(r'(<\w+[^>]*?)\s+(\w+="[^"]*")\s+\2')
    while True:
        new_text, count = pattern.subn(r'\1 \2', xml_text)
        if count == 0:
            break
        xml_text = new_text
    return xml_text

base_folder = "tenhou_source_data/tenhou_haifu"
batch_size   = 300
max_retries  = 5  # 最大リトライ回数

# ロギング設定
log_folder = "logs"
os.makedirs(log_folder, exist_ok=True)
logging.basicConfig(
    filename=os.path.join(log_folder, "error_urls.log"),
    level=logging.ERROR,
    format="%(asctime)s [%(levelname)s] %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
)

total_rows    = len(dataset_sanma_url_df)
total_batches = (total_rows + batch_size - 1) // batch_size
bar_length    = 25

for i in range(0, total_rows, batch_size):
    batch_df = dataset_sanma_url_df.iloc[i:i + batch_size]

    for idx, row in batch_df.iterrows():
        url       = row['url']
        date_str  = row['date'].strftime("%Y_%m_%d")
        time_str  = row['time'].replace(":", "_")
        year_fold = os.path.join(base_folder, str(row['year']))
        os.makedirs(year_fold, exist_ok=True)

        filename = os.path.join(
            year_fold,
            f"tenhou_haifu_{date_str}_{time_str}_{idx}.xml"
        )

        if os.path.exists(filename):
            continue  # 既存ファイルはスキップ

        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
        }

        retry = 0
        while True:
            try:
                response = requests.get(url, headers=headers, timeout=10)

                # 404/410 は即スキップ＆ログ
                if response.status_code in (404, 410):
                    msg = f"スキップ(HTTP {response.status_code}) index={idx}: {url}"
                    print("⚠️ " + msg)
                    logging.error(msg)
                    break

                response.raise_for_status()

                # 重複属性除去プリプロセス
                cleaned = dedupe_attrs(response.text)

                # XML をパース＆整形保存
                dom = xml.dom.minidom.parseString(cleaned)
                with open(filename, "w", encoding="utf-8") as f:
                    f.write(dom.toprettyxml(indent="  "))

                break  # 成功したらループ抜け

            except requests.exceptions.HTTPError as e:
                retry += 1
                if retry > max_retries:
                    msg = f"URLスキップ(index={idx}, retries={retry}): {url} - HTTPError {e.response.status_code}"
                    print("❌ " + msg)
                    logging.error(msg)
                    break
                wait = 2 ** retry
                print(f"❌ HTTPError({e.response.status_code}) index={idx} - リトライ {retry}/{max_retries} 待機:{wait}s")
                time.sleep(wait)

            except Exception as e:
                retry += 1
                if retry > max_retries:
                    msg = f"URLスキップ(index={idx}, retries={retry}): {url} - {e}"
                    print("❌ " + msg)
                    logging.error(msg)
                    break
                wait = 2 ** retry
                print(f"❌ エラー(index={idx}): {e} - リトライ {retry}/{max_retries} 待機:{wait}s")
                time.sleep(wait)

    # プログレスバー表示
    current_batch = i // batch_size + 1
    progress      = current_batch / total_batches
    bar = '█' * int(bar_length * progress) + '-' * (bar_length - int(bar_length * progress))
    print(f"\r🕒 バッチ {current_batch}/{total_batches} 完了 [{bar}] {progress*100:.1f}%", end='')

print("\n✅ 全バッチ処理完了！")
# Out:
# 🕒 バッチ 2871/2871 完了 [█████████████████████████] 100.0%
# ✅ 全バッチ処理完了！
